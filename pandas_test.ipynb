# %%
import pandas as pd

# %% [markdown]
# # Загрузка и пример данных

# %%
data = pd.read_csv('data/data_2025-03-12_14-40-21.csv')
len(data)

# %%
data.head(10)

# %% [markdown]
# # Берем только отсчеты

# %%
values_data = data.drop(columns=['Num Pack', 'Antenna', 'Window', 'Diag', 'System_type', 'Drone_type', 'Timestamp'])
values_data.head(5)

# %% [markdown]
# # Отсчеты первого наблюдения

# %%
values_data.iloc[0]

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Включаем интерактивный режим
plt.ion()

# Отключаем ненужные колонки один раз
filtered_data = selected_data.drop(columns=['Num Pack', 'Antenna', 'Window', 'Diag', 'System_type', 'Drone_type', 'Timestamp'])

# Проверяем, что данные остались
if filtered_data.empty:
    raise ValueError("После удаления столбцов данные отсутствуют. Проверьте входные данные.")

# Проверяем, что данные числовые
filtered_data = filtered_data.apply(pd.to_numeric, errors='coerce')

# Создаем фигуру и оси
fig, ax = plt.subplots()

# Цикл для обновления графика
for i in range(40):
    ax.clear()  # Очищаем текущий график
    row = filtered_data.iloc[i]  # Выбираем i-ю строку
    if row.empty:
        print(f"Строка {i} пустая. Пропускаем.")
        continue

    row.plot(ax=ax)  # Рисуем новые данные
    ax.set_title(f'Row {i}')  # Обновляем заголовок
    plt.draw()  # Перерисовываем график
    plt.pause(0.5)  # Пауза для обновления (в секундах)

# Отключаем интерактивный режим после завершения
plt.ioff()
plt.show()  # Показываем финальный график
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[46], line 31
#      29     ax.set_title(f'Row {i}')  # Обновляем заголовок
#      30     plt.draw()  # Перерисовываем график
# ---> 31     plt.pause(0.5)  # Пауза для обновления (в секундах)
#      33 # Отключаем интерактивный режим после завершения
#      34 plt.ioff()
#
# File ~/Desktop/work/sample_collector/coll/lib/python3.12/site-packages/matplotlib/pyplot.py:758, in pause(interval)
#     756         canvas.draw_idle()
#     757     show(block=False)
# --> 758     canvas.start_event_loop(interval)
#     759 else:
#     760     time.sleep(interval)
#
# File ~/Desktop/work/sample_collector/coll/lib/python3.12/site-packages/matplotlib/backend_bases.py:2365, in FigureCanvasBase.start_event_loop(self, timeout)
#    2363 while self._looping and counter * timestep < timeout:
#    2364     self.flush_events()
# ...

# %% [markdown]
# # Селекция по антенне и окну

# %%
selected_data = data[(data['Window'] == 2) & (data['Antenna'] == 1)]
selected_data
