# %%
import pandas as pd

# %% [markdown]
# # Загрузка и пример данных

# %%
data = pd.read_csv('data/2025-02-17_15:38_data.csv')
data.head(5)
# Out:
#      data[0]    data[1]    data[2]    data[3]    data[4]    data[5]  \
# 0 -23.724130 -82.846640 -85.815994 -40.487137  -9.855880 -52.670380
# 1 -34.496174 -48.941082  -8.382666 -20.423681 -33.155937  -3.190306
# 2 -57.034462 -83.966324 -74.360630 -55.952854 -29.261274  -5.960996
# 3 -49.735306  -3.758673 -41.224655 -28.315577 -20.009222  -6.271378
# 4 -27.031662 -61.492200 -75.030380 -94.626660 -26.369024 -82.629820
#
#      data[6]    data[7]    data[8]    data[9]  ...  data[2043]  data[2044]  \
# 0 -41.841953 -90.371140 -68.569360 -82.249370  ...  -23.904700  -99.380290
# 1  -3.307498  -0.160970 -40.544880  -6.708192  ...  -36.143925  -36.397700
# 2 -37.632244 -82.816765 -58.320360  -3.571861  ...  -80.177010  -94.920000
# 3 -79.210754 -13.036032 -75.456375 -62.951890  ...  -58.416860  -11.715746
# 4 -59.879368 -91.867950 -64.629800 -61.107372  ...  -11.735241  -24.221718
#
#    data[2045]  data[2046]  data[2047]  Num Pack  Antenna  Window  Diag  \
# ...

# %% [markdown]
# # Берем только отсчеты

# %%
values_data = data.drop(columns=['Num Pack', 'Antenna', 'Window', 'Diag', 'System_type'])
values_data.head(5)
# Out:
#      data[0]    data[1]    data[2]    data[3]    data[4]    data[5]  \
# 0 -23.724130 -82.846640 -85.815994 -40.487137  -9.855880 -52.670380
# 1 -34.496174 -48.941082  -8.382666 -20.423681 -33.155937  -3.190306
# 2 -57.034462 -83.966324 -74.360630 -55.952854 -29.261274  -5.960996
# 3 -49.735306  -3.758673 -41.224655 -28.315577 -20.009222  -6.271378
# 4 -27.031662 -61.492200 -75.030380 -94.626660 -26.369024 -82.629820
#
#      data[6]    data[7]    data[8]    data[9]  ...  data[2038]  data[2039]  \
# 0 -41.841953 -90.371140 -68.569360 -82.249370  ...  -35.780270  -14.029753
# 1  -3.307498  -0.160970 -40.544880  -6.708192  ...  -38.320843  -35.300260
# 2 -37.632244 -82.816765 -58.320360  -3.571861  ...  -94.176765  -24.111574
# 3 -79.210754 -13.036032 -75.456375 -62.951890  ...  -18.887262  -86.955414
# 4 -59.879368 -91.867950 -64.629800 -61.107372  ...  -47.560684  -57.202920
#
#    data[2040]  data[2041]  data[2042]  data[2043]  data[2044]  data[2045]  \
# ...

# %% [markdown]
# # Отсчеты первого наблюдения

# %%
values_data.iloc[0]
# Out:
# data[0]      -23.724130
# data[1]      -82.846640
# data[2]      -85.815994
# data[3]      -40.487137
# data[4]       -9.855880
#                 ...
# data[2043]   -23.904700
# data[2044]   -99.380290
# data[2045]   -80.058350
# data[2046]    -6.791001
# data[2047]   -24.993969
# Name: 0, Length: 2048, dtype: float64
