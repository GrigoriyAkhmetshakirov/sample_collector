# %%
import pandas as pd

# %% [markdown]
# # Загрузка и пример данных

# %%
data = pd.read_csv('data/data_2025-03-17_14-25-46.csv')
data['Timestamp'] = data['Timestamp'].apply(lambda x: pd.to_datetime(x, format='%Y-%m-%d_%H-%M-%S'))
len(data)
# Out:
# 5006

# %%
data.tail(10)

# %% [markdown]
# # Берем только отсчеты

# %%
values_data = data.drop(columns=['Num Pack', 'Antenna', 'Window', 'System_type', 'Drone_type', 'Timestamp', 'Drone_is_present'])
values_data.head(5)

# %% [markdown]
# # Отсчеты первого наблюдения

# %%
values_data.iloc[0]

# %% [markdown]
# # Селекция по антенне и окну

# %%
selected_data = data[(data['Window'] == 2) & (data['Antenna'] == 1)]
selected_data.plot(y=['Mean'], x='Timestamp', kind='bar')
# Out:
# <Axes: xlabel='Timestamp'>
