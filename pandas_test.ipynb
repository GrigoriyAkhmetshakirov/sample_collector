# %%
import pandas as pd

# %% [markdown]
# # Загрузка и пример данных

# %%
data = pd.read_csv('data/data_2025-03-13_09-02-32.csv')
len(data)
# Out:
# 1834

# %%
data.head(10)

# %% [markdown]
# # Берем только отсчеты

# %%
values_data = data.drop(columns=['Num Pack', 'Antenna', 'Window', 'Diag', 'System_type', 'Drone_type', 'Timestamp'])
values_data.head(5)
# Out:
#      data[0]    data[1]   data[2]    data[3]    data[4]   data[5]    data[6]  \
# 0 -83.756615 -83.769800 -83.05144 -83.257706 -86.339096 -81.09461 -86.435196
# 1 -81.243620 -85.295105 -84.30688 -83.555756 -83.197530 -86.86194 -82.129440
# 2 -82.956314 -83.030160 -87.56575 -85.609790 -82.110960 -88.47718 -82.932130
# 3 -84.081635 -88.049385 -80.98003 -82.333060 -80.843340 -86.95431 -82.678990
# 4 -82.883040 -88.889915 -86.06621 -84.429580 -87.268456 -85.95303 -84.644714
#
#     data[7]   data[8]    data[9]  ...  data[2038]  data[2039]  data[2040]  \
# 0 -89.30426 -83.09809 -85.863470  ...  -89.360100  -84.501080   -89.52497
# 1 -83.18824 -88.97157 -81.626274  ...  -83.186340  -86.506325   -87.55272
# 2 -85.12346 -82.28347 -84.852800  ...  -86.447975  -83.661740   -80.39260
# 3 -84.15198 -84.93149 -82.396870  ...  -83.298710  -85.283380   -89.31899
# 4 -85.82417 -86.07165 -86.476395  ...  -87.945840  -83.275740   -85.62263
#
# ...

# %% [markdown]
# # Отсчеты первого наблюдения

# %%
values_data.iloc[0]
# Out:
# data[0]      -83.756615
# data[1]      -83.769800
# data[2]      -83.051440
# data[3]      -83.257706
# data[4]      -86.339096
#                 ...
# data[2043]   -87.252380
# data[2044]   -91.153206
# data[2045]   -85.994470
# data[2046]   -84.838170
# data[2047]   -87.058210
# Name: 0, Length: 2048, dtype: float64

# %% [markdown]
# # Селекция по антенне и окну

# %%
selected_data = data[(data['Window'] == 2) & (data['Antenna'] == 1)]
selected_data
# Out:
#         data[0]    data[1]    data[2]    data[3]    data[4]    data[5]  \
# 39   -86.291670 -90.621630 -90.773730 -90.715020 -88.347000 -92.400090
# 135  -78.072690 -77.697110 -83.957504 -78.335100 -75.424870 -72.197790
# 231  -87.237144 -91.031166 -88.342220 -90.349170 -87.757290 -88.317820
# 327  -80.040860 -73.926320 -79.843690 -82.097420 -83.284470 -80.530970
# 423  -92.095470 -89.508690 -90.786224 -87.892120 -88.632510 -91.946030
# 519  -79.493385 -71.831604 -78.081320 -79.738190 -76.048070 -74.922600
# 615  -90.958176 -89.208350 -87.504130 -91.169560 -89.993490 -88.758730
# 711  -76.563570 -81.488625 -77.905205 -77.023390 -75.786224 -77.977066
# 807  -87.235020 -89.209910 -88.031810 -85.318344 -85.452415 -89.302826
# 903  -77.970840 -77.899216 -76.272690 -70.531400 -79.773050 -81.140366
# 999  -87.516720 -90.658650 -87.593750 -88.999520 -92.370820 -91.261380
# 1095 -78.300510 -76.850250 -81.922630 -73.448204 -79.920876 -75.142750
# ...
