# %%
import pandas as pd

# %% [markdown]
# # Загрузка и пример данных

# %%
data = pd.read_csv('data/data_2025-03-12_14-40-21.csv')
len(data)
# Out:
# 4978

# %%
data.head(10)

# %% [markdown]
# # Берем только отсчеты

# %%
values_data = data.drop(columns=['Num Pack', 'Antenna', 'Window', 'Diag', 'System_type', 'Drone_type'])
values_data.head(5)

# %% [markdown]
# # Отсчеты первого наблюдения

# %%
values_data.iloc[0]

# %%
values_data.iloc[0].plot();

# %% [markdown]
# # Селекция по антене и окну

# %%
selected_data = data[(data['Window'] == 2) & (data['Antenna'] == 1)]
selected_data
# Out:
#        data[0]   data[1]    data[2]    data[3]    data[4]    data[5]  \
# 88   -7.097641 -8.519730 -13.111420 -22.480300 -67.787980 -39.361748
# 256  -7.101242 -8.523254 -13.114380 -22.479416 -68.892630 -39.416008
# 347  -7.100159 -8.522461 -13.114822 -22.485115 -67.348780 -39.390700
# 436  -7.097427 -8.519485 -13.110733 -22.475876 -67.787025 -39.424057
# 524  -7.104279 -8.526657 -13.119446 -22.491623 -68.936060 -39.388084
# 612  -7.097748 -8.520065 -13.112717 -22.485107 -66.753006 -39.349976
# 706  -7.099930 -8.522202 -13.114593 -22.485947 -68.594440 -39.371810
# 793  -7.098892 -8.521240 -13.113907 -22.485916 -67.422380 -39.380615
# 881  -7.097733 -8.520111 -13.112991 -22.486313 -67.860504 -39.344520
# 972  -7.099335 -8.521530 -13.113525 -22.482758 -68.260180 -39.384018
# 1061 -7.096832 -8.519196 -13.111893 -22.483360 -67.121475 -39.374954
# 1149 -7.100861 -8.523102 -13.115250 -22.484459 -67.772285 -39.409790
# 1239 -7.097565 -8.519806 -13.111664 -22.477707 -67.635020 -39.445076
# ...
