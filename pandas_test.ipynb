# %%
import pandas as pd
from matplotlib import pyplot as plt

# %% [markdown]
# # Загрузка и пример данных

# %%
data = pd.read_csv('data/data_2025-03-19_12-05-35.csv')
data['Timestamp'] = data['Timestamp'].apply(lambda x: pd.to_datetime(x, format='%Y-%m-%d_%H-%M-%S'))
len(data)
# Out:
# 27

# %%
data.head(10)
# Out:
#      data[0]    data[1]    data[2]    data[3]    data[4]    data[5]  \
# 0 -98.685265 -92.803790 -94.284996 -92.960815 -90.470690 -94.552345
# 1 -92.109950 -98.357765 -95.250960 -93.677200 -95.522766 -92.775894
# 2 -91.566710 -91.645790 -95.556780 -92.367020 -91.485756 -98.478340
# 3 -97.983190 -90.001830 -98.227325 -96.093390 -90.669205 -98.770140
# 4 -99.177734 -93.772590 -99.287360 -99.196020 -99.267840 -96.101654
# 5 -92.916824 -94.650950 -99.021750 -97.354970 -95.935700 -95.457855
# 6 -95.975990 -98.883260 -91.123170 -95.337740 -97.425790 -98.727806
# 7 -94.886505 -96.708120 -94.558030 -93.480890 -92.535670 -97.007200
# 8 -92.128870 -95.384490 -94.144170 -95.360880 -90.749535 -95.426660
# 9 -90.708670 -99.863300 -92.501170 -93.624650 -95.656590 -90.070080
#
#      data[6]    data[7]    data[8]    data[9]  ...  data[2046]  data[2047]  \
# 0 -92.042990 -96.421010 -91.881386 -97.000270  ...  -56.174920  -91.859150
# 1 -95.449040 -97.440390 -94.327690 -98.750280  ...  -51.712727  -83.370230
# 2 -90.584940 -95.138140 -92.944970 -94.440094  ...  -95.713260  -64.772255
# 3 -90.717926 -96.465530 -99.009810 -90.428040  ...  -85.422760  -98.629135
# 4 -93.213480 -96.098900 -91.496025 -94.621990  ...  -94.585075  -97.576020
# 5 -95.677970 -90.138870 -93.756520 -91.288820  ...  -82.413734  -99.652940
# 6 -92.195710 -97.044785 -98.501850 -92.681140  ...  -92.627975  -90.076630
# 7 -98.533970 -95.763200 -95.497505 -94.250580  ...  -51.026970  -68.832650
# 8 -99.496800 -91.617090 -91.886450 -96.373520  ...  -99.501550  -80.645990
# 9 -92.531425 -96.138860 -92.146480 -92.889520  ...  -91.195100  -78.060270
#
#         Mean  Num Pack  Antenna  Window  System_type  Drone_type  \
# 0 -70.065506       320        1      12       Type 1         DJI
# 1 -69.943800       330        1       6       Type 1         DJI
# 2 -70.191956       340        1      10       Type 1         DJI
# 3 -70.000680       350        1      10       Type 1         DJI
# 4 -70.011080       360        1       4       Type 1         DJI
# 5 -70.002810       370        1      12       Type 1         DJI
# 6 -70.131805       380        1       6       Type 1         DJI
# 7 -69.763535       390        1      14       Type 1         DJI
# 8 -69.803055       400        1      13       Type 1         DJI
# 9 -69.929565       410        1       8       Type 1         DJI
#
#    Drone_is_present           Timestamp
# 0                 0 2025-03-19 12:05:35
# 1                 0 2025-03-19 12:05:35
# 2                 0 2025-03-19 12:05:35
# 3                 0 2025-03-19 12:05:35
# 4                 0 2025-03-19 12:05:35
# 5                 0 2025-03-19 12:05:35
# 6                 0 2025-03-19 12:05:35
# 7                 0 2025-03-19 12:05:35
# 8                 0 2025-03-19 12:05:36
# 9                 0 2025-03-19 12:05:36
#
# [10 rows x 2056 columns]

# %% [markdown]
# # Берем только отсчеты

# %%
values_data = data.drop(columns=['Num Pack', 'Antenna', 'Window', 'System_type', 'Drone_type', 'Timestamp', 'Drone_is_present', 'Mean'])
values_data.head(5)
# Out:
#      data[0]   data[1]    data[2]    data[3]    data[4]    data[5]    data[6]  \
# 0 -98.484270 -95.36256 -91.699295 -97.757950 -92.571060 -97.104546 -93.252045
# 1 -92.484420 -94.96885 -91.380370 -95.498886 -99.775375 -90.724460 -95.434620
# 2 -97.346940 -96.84089 -94.804450 -93.449500 -93.363000 -95.139660 -95.894066
# 3 -99.731674 -98.92079 -90.808960 -95.191826 -92.569370 -98.000150 -92.470310
# 4 -97.239395 -98.40830 -90.345670 -91.001480 -95.252144 -92.154366 -93.674260
#
#      data[7]    data[8]   data[9]  ...  data[2038]  data[2039]  data[2040]  \
# 0 -99.524270 -92.562225 -90.78998  ...  -62.959114  -87.412895  -77.867770
# 1 -90.951096 -96.966780 -99.89970  ...  -57.501090  -83.633070  -95.714180
# 2 -92.019980 -99.838330 -97.13106  ...  -70.828125  -73.908970  -67.908460
# 3 -99.742550 -94.763794 -90.02998  ...  -62.140373  -50.569107  -63.311096
# 4 -93.437040 -97.254340 -98.33761  ...  -70.033230  -69.623795  -91.204560
#
#    data[2041]  data[2042]  data[2043]  data[2044]  data[2045]  data[2046]  \
# 0   -61.28818  -92.709740  -77.962410  -86.735520  -56.592728  -74.761300
# 1   -72.26010  -65.947610  -82.503090  -72.041100  -88.216870  -65.796960
# 2   -78.19858  -84.104150  -53.863186  -62.620420  -77.672810  -62.604523
# 3   -72.71149  -92.784280  -52.715496  -69.976036  -85.873530  -54.091390
# 4   -76.96361  -51.321274  -53.099575  -95.914750  -83.262794  -71.598430
#
#    data[2047]
# 0  -68.327710
# 1  -84.041405
# 2  -85.996690
# 3  -88.603226
# 4  -76.388330
#
# [5 rows x 2048 columns]

# %% [markdown]
# # Отсчеты первого наблюдения

# %%
values_data.iloc[0]

# %% [markdown]
# # Селекция по антенне и окну

# %%
selected_data = data[(data['Window'] == 2) & (data['Antenna'] == 1)]

# %% [markdown]
# # График среднего

# %%
selected_data.plot(y=['Mean'], x='Timestamp', kind='bar');
